# %% [markdown]
# # 어텐션 메커니즘과 트랜스포머

# %% [markdown]
# 허깅페이스로 KoBART 모델 로드하기

# %%
from transformers import pipeline

pipe = pipeline(task='summarization', device=0)
# Out:
# 2025-12-03 09:10:21.409634: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-03 09:10:21.975293: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-03 09:10:24.196829: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0

# %%
pipe = pipeline(task='summarization',
model='sshleifer/distilbart-cnn-12-6', device=0)
# Out:
# Device set to use cuda:0

# %%
sample_text = """Vincent Willem van Gogh was a Dutch Post-Impressionist
painter who is among the most famous and influential figures in the history
of Western art. In just over a decade, he created approximately 2100
artworks, including around 860 oil paintings, most of them in the last two
years of his life. His oeuvre includes landscapes, still lifes, portraits,
and self-portraits, most of which are characterised by bold colours and
dramatic brushwork that contributed to the rise of expressionism in modern
art. Van Gogh's work was beginning to gain critical attention before he died
from a self-inflicted gunshot at age 37. During his lifetime, only one of
Van Gogh’s paintings. The Red Vineyard, was sold.
"""
pipe(sample_text)
# Out:
# [{'summary_text': ' Vincent Willem van Gogh was a Dutch Post-Impressionist painter who is among the most famous and influential figures in the history of Western art . In just over a decade, he created approximately 2100 artworks, including around 860 oil paintings, most of them in the last two years of his life . His oeuvre includes landscapes, still lifes, portraits and self-portraits .'}]

# %%
kobart = pipeline(task='summarization',
    model='EbanLee/kobart-summary-v3', device=0)
# Out:
# You passed `num_labels=3` which is incompatible to the `id2label` map of length `2`.
# You passed `num_labels=3` which is incompatible to the `id2label` map of length `2`.
# Device set to use cuda:0

# %%
ko_text = """
하나, ‘입문자 맞춤형 7단계 구성’을 따라가며 체계적으로 반복하는 탄탄한 학습 설계!
이 책은 데이터 분석의 핵심 내용을 7단계에 걸쳐 반복 학습하면서 자연스럽게 머릿속에 기억되도록 구성했습니다. [핵심 키워드]와 [시작하기 전에]에서 각 절의 주제에 대한 대표 개념을 워밍업하고, 이론과 실습을 거쳐 마무리에서는 [핵심 포인트]와 [확인 문제]로 한번에 복습합니다. ‘혼자 공부할 수 있는’ 커리큘럼을 그대로 믿고 끝까지 따라가다 보면 데이터 분석 공부가 난생 처음인 입문자도 무리 없이 책을 끝까지 마칠 수 있습니다!
둘, 실제로 일어날 법한 흥미로운 스토리에 담긴 문제를 직접 해결하며 익히는 ‘진짜’ 데이터 분석!
현장감 넘치는 스토리를 통해 데이터를 다루는 방법을 알려 주어 ‘파이썬’과 ‘데이터’가 낯설어도 몰입감 있는 학습을 할 수 있도록 구성했습니다. 이 책에서는 API와 웹 스크래핑을 통해 실제 도서관 데이터와 온라인 서점 웹사이트에서 데이터를 가져오는 등 내 주변에 있는 데이터를 직접 수집할 수 있는 방법을 가이드합니다. 또한 판다스, 넘파이, 맷플롯립 등 데이터 분석에 유용한 각종 파이썬 라이브러리를 활용해 보며 코딩 감각을 익히고, 핵심 통계 지식으로 기본기를 탄탄하게 다질 수 있습니다. 마지막에는 분석을 바탕으로 미래를 예측하는 머신러닝까지 맛볼 수 있어 데이터 분석의 처음부터 끝까지 제대로 배울 수 있습니다.
셋, ‘혼공’의 힘을 실어줄 동영상 강의와 혼공 학습 사이트 지원!
책으로만 학습하기엔 여전히 어려운 입문자를 위해 저자 직강 동영상도 지원합니다. 또한 학습을 하며 궁금한 사항은 언제든지 저자에게 질문할 수 있도록 학습 사이트를 제공합니다. 저자가 질문 하나하나에 직접 답변을 달아 주는 것은 물론, 관련 최신 기술과 정보도 얻을 수 있습니다. 게다가 혼자 공부하고 싶지만 정작 혼자서는 자신 없는 사람들을 위해 혼공 학습단을 운영합니다. 혼공 학습단과 함께하면 마지막까지 포기하지 않고 완주할 수 있을 것입니다.
▶ https://hongong.hanbit.co.kr
▶ https://github.com/rickiepark/hg-da
넷, 언제 어디서든 가볍게 볼 수 있는 혼공 필수 [용어 노트] 제공!
꼭 기억해야 할 핵심 개념과 용어만 따로 정리한 [용어 노트]를 제공합니다. 처음 공부하는 사람들이 프로그래밍을 어려워하는 이유는 낯선 용어 때문입니다. 그러나 어려운 것이 아니라 익숙하지 않아서 헷갈리는 것이므로, 용어나 개념이 잘 생각나지 않을 때는 언제든 부담 없이 [용어 노트]를 펼쳐 보세요. 제시된 용어 외에도 새로운 용어를 추가하면서 자신만의 용어 노트를 완성해가는 과정도 또 다른 재미가 될 것입니다.
"""

kobart(ko_text)
# Out:
# [{'summary_text': '이 책은 데이터 분석의 핵심 내용을 7단계에 걸쳐 반복 학습하면서 머릿속에 기억되도록 구성했습니다. 독자 공부할 수 있는 커리큘럼을 그대로 믿고 끝까지 따라가다 보면 데이터 분석 공부가 난생 처음인 입문자도 무리 없이 책을 끝까지 마칠 수 있습니다. 현장감 넘치는 스토리를 통해 데이터를 다루는 방법을 알려 주어 몰입감 있는 학습을 할 수 있도록 구성했습니다. 저자가 질문 하나하나에 직접 답변을 달아 주는 것은 물론, 최신 기술과 정보도 얻을 수 있습니다. 혼공 학습단과 함께하면 마지막까지 포기하지 않고 완주할 수 있을 것입니다. '}]

# %% [markdown]
# 텍스트 토큰화

# %%
print(kobart.tokenizer.vocab_size)
# Out:
# 30000

# %%
len(kobart.tokenizer)
# Out:
# 30000

# %%
vocab = kobart.tokenizer.vocab
len(vocab)
# Out:
# 30000

# %%
list(vocab.items())[:10]
# Out:
# [('▁전개', 17628),
#  ('餓', 8659),
#  ('넼', 9579),
#  ('댇', 9779),
#  ('곶', 9116),
#  ('杼', 4593),
#  ('帅', 3650),
#  ('挚', 4180),
#  ('▁상환', 21774),
#  ('떵', 10090)]

# %%
tokens = kobart.tokenizer.tokenize('혼자 만들면서 공부하는 딥러닝')
print(tokens)
# Out:
# ['▁혼자', '▁만들', '면서', '▁공부', '하는', '▁', '딥', '러', '닝']

# %%
kobart.tokenizer.convert_tokens_to_ids(tokens)
# Out:
# [16814, 14397, 14125, 16962, 14049, 1700, 10021, 10277, 9747]

# %%
token_ids = kobart.tokenizer.encode('혼자 만들면서 공부하는 딥러닝')
print(token_ids)
# Out:
# [0, 16814, 14397, 14125, 16962, 14049, 1700, 10021, 10277, 9747, 1]

# %%
tokens = kobart.tokenizer.convert_ids_to_tokens(token_ids)
print(tokens)
# Out:
# ['<s>', '▁혼자', '▁만들', '면서', '▁공부', '하는', '▁', '딥', '러', '닝', '</s>']

# %%
kobart.tokenizer.decode(token_ids)
# Out:
# '<s> 혼자 만들면서 공부하는 딥러닝</s>'

# %% [markdown]
# EXAONE-3.5로 상품 질문에 대한 대답 생성하기

# %%
from transformers import AutoTokenizer

exaone_tokenizer = AutoTokenizer.from_pretrained(
    "LGAI-EXAONE/EXAONE-3.5-2.4B-Instruct")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/563 [00:00<?, ?B/s]

# %%
from transformers import pipeline

pipe = pipeline(task="text-generation",
    model="LGAI-EXAONE/EXAONE-3.5-2.4B-Instruct",
    tokenizer=exaone_tokenizer,
    device=0, trust_remote_code=True)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# configuration_exaone.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/LGAI-EXAONE/EXAONE-3.5-2.4B-Instruct:
# - configuration_exaone.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_exaone.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/LGAI-EXAONE/EXAONE-3.5-2.4B-Instruct:
# - modeling_exaone.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.65G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/134 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
messages = [
{"role": "system",
"content": "너는 쇼핑몰 홈페이지에 올라온 질문에 대답하는 Q&A 챗봇이야. \
확정적인 답변을 하지 말고 제품 담당자가 정확한 답변을 하기 위해 \
시간이 필요하다는 간단하고 친절한 답변을 생성해줘."},
{"role": "user", "content": "이 다이어리에 내년도 공휴일이 표시되어 있나요?"}
]

# %%
pipe(messages, max_new_tokens=200)
# Out:
# [{'generated_text': [{'role': 'system',
#     'content': '너는 쇼핑몰 홈페이지에 올라온 질문에 대답하는 Q&A 챗봇이야. 확정적인 답변을 하지 말고 제품 담당자가 정확한 답변을 하기 위해 시간이 필요하다는 간단하고 친절한 답변을 생성해줘.'},
#    {'role': 'user', 'content': '이 다이어리에 내년도 공휴일이 표시되어 있나요?'},
#    {'role': 'assistant',
#     'content': '죄송합니다만, 현재 저희 챗봇은 실시간 정보 업데이트가 제한적이어서 내년의 공휴일 정보를 바로 제공해 드리기 어렵습니다. 정확한 답변을 위해서는 제품 담당자에게 확인을 요청하시는 것이 가장 좋을 것 같습니다. 담당자님께 연락하시면 가장 최신 정보를 알려드릴 수 있을 거예요! 감사합니다.'}]}]

# %%
pipe(messages, max_new_tokens=500, return_full_text=False)
# Out:
# [{'generated_text': '안녕하세요!   다이어리 내용에 대한 질문에 대해 답변 드리려고 하는데요, 조금 더 자세히 설명해주시면 도움을 드리기 쉬울 것 같아요. \n\n예를 들어, 어떤 종류의 공휴일을 확인하고 싶으신가요? (국가 공휴일, 지역 공휴일 등) 그리고 언제까지 구매를 원하시는지 알려주시면 더욱 정확한 답변을 드릴 수 있을 것 같습니다. 시간이 조금 걸릴 수 있지만, 최대한 빠르게 정확한 답변을 준비해드리겠습니다! 감사합니다. 😊'}]

# %%
output = pipe(messages, max_new_tokens=200, return_full_text=False,
    do_sample=True)
print(output[0]['generated_text'])
# Out:
# 안녕하세요! 다이어리에 내년도 공휴일 정보가 포함되어 있는지 자세히 확인해 드리기 위해 잠시 시간이 필요합니다. 담당자분께서 정확한 정보를 제공해 주시겠지만, 최대한 빨리 답변 드리겠습니다. 기다리시면서 다른 궁금한 점이 있으시면 언제든지 알려주세요!

# %%
# 난수 발생의 시드 값 지정
from transformers import set_seed
set_seed(42)

# %% [markdown]
# 토큰 디코딩 전략

# %%
import numpy as np

logits = np.array([1, 2, 3, 4, 100])

# %%
from scipy.special import softmax

probas = softmax(logits)
print(probas)
# Out:
# [1.01122149e-43 2.74878501e-43 7.47197234e-43 2.03109266e-42
#  1.00000000e+00]

# %%
np.random.multinomial(100, probas)
# Out:
# array([  0,   0,   0,   0, 100])

# %%
probas = softmax(logits/100)
np.random.multinomial(100, probas)
# Out:
# array([11, 12, 11, 22, 44])

# %%
output = pipe(messages, max_new_tokens=200, return_full_text=False,
              do_sample=True, temperature=10.0)
print(output[0]['generated_text'])
# Out:
# 제가 아직 고객 대표 여러분 전용 기능 향상 방향이라 시간제한 문제엔 맞춰진 특정 대응엔 관여 못할지도 몰라 이렇게 드릴게요체 설명 해 드려봅니다._Yes / Please provide me the details about date support, like if it captures future significant festivals specifically by next week for Korea standards you seek on your planned year calendar; currently hitting us momentarily while teams gather more timely resources ahead directly helps with those inquiries professionally swiftly. 정확함 대신 이러다보하니, 앞 시점 실제 관련 내용을 찾아보시길 요청하여드리길 부탁해하려 그러다보던차 빠르오지만 그에겐 추가 상세 도움의 시간 요청도 부탁드려요! 팀한다니 시간 절약해주기 부탁드려요 :-)   간단히 설명 드립니다:, 각 공식 공휴일 지정 업데이트와 날짜 체계 부분에 세부 내용 찾아보실수나 담당자 정보 좀 전달 되어 실질 대응 보다 정확케 해 나갈 노력 기울이심에 좋은지 체크 요청들!

# %%
output = pipe(messages, max_new_tokens=200, return_full_text=False,
    do_sample=True, temperature=0.001)
print(output[0]['generated_text'])
# Out:
# 안녕하세요! 다이어리에 내년의 공휴일 정보가 포함되어 있는지 확인해 드리기 위해 잠시 시간을 내주실 수 있을까요? 제품 담당자가 바로 확인 후 정확한 답변을 드릴 수 있도록 하겠습니다. 기다리시면 곧 알려드리겠습니다! 감사합니다.

# %% [markdown]
# top-k 샘플링

# %%
output = pipe(messages, max_new_tokens=200, return_full_text=False,
    do_sample=True, top_k=10)
print(output[0]['generated_text'])
# Out:
# 안녕하세요! 다이어리에 내년의 공휴일 정보가 포함되어 있는지에 대한 답변을 드리려면 좀 더 자세히 확인이 필요합니다. 현재로선 정확한 정보를 제공하기 어렵습니다. 혹시 제품 담당자님께 연락하시거나, 상품 페이지의 고객 서비스 옵션을 이용해 주시면 더 빠르게 도와드릴 수 있을 것 같아요. 감사합니다! 😊

# %%
output = pipe(messages, max_new_tokens=200, return_full_text=False,
    do_sample=True, top_k=10, temperature=10.0)
print(output[0]['generated_text'])
# Out:
# 현재 확인이 불가하기 하지만 저희가 최대한 도움 드리자면, 저희 시스템에는 정확합니다! 다이어리 제품 담당자께 바로 확인 부탁 드려 보시나요? 그럼 내년에 공휴일 여부 확인하시게 될지 빨리 도움 드리지 못해죄송습니다 😊 담당자님을 기다리는 동안 잠시 참고 부탁드립니다~! 궁금하시고 빠른 대답을 기다리티겠다는 걸 압니당! 감사하네요~ 👍  확인하시는 시간 잘 부탁드립니다❤🚨✨  감사드립니다 😊🏕️✏‍♀👨⚒_enlighten! 🗳

# %% [markdown]
# top-p 샘플링

# %%
output = pipe(messages, max_new_tokens=200, return_full_text=False,
    do_sample=True, top_p=0.9)
print(output[0]['generated_text'])
# Out:
# 안녕하세요! 다이어리에 내년의 공휴일 정보가 포함되어 있는지 확인하는 데 도움을 드리려고 합니다. 정확한 답변을 위해서는 제품 담당자께 문의하시는 것이 가장 좋을 것 같아요. 담당자께서는 다이어리의 최신 정보와 업데이트 사항을 알려드릴 수 있을 거예요. 혹시 담당자 연락처나 추가 정보가 있다면 함께 알려주시면 더 도움이 될 것 같습니다!

# %%
output = pipe(messages, max_new_tokens=200, return_full_text=False,
    do_sample=True, temperature=2.0, top_k=100, top_p=0.9)
print(output[0]['generated_text'])
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 네orrh요, 좋은 질문이네요! 해당 다이어리에 annum별 정확한 공휴일 정보가 미리 제작 내부에 모두 포함된 경우가 많이 있으나, 최신 정확성을 위해서는 곧 각 쇼핑몰에 연락 부탁드릴 예정입니다. 신속하게 확인해볼 것이라고 말씀드려 놓았으니 기다리고 계실까해요. 편하실 때 다시 확인요청 주실 수 있어요! 빠른 답변 기다릴게요. 감사해요. 😊🖂️

# %% [markdown]
# 오픈AI의 API 사용해보기

# %% [markdown]
# 오픈 AI API로 상품 질문에 대한 대답 생성하기

# %%
from openai import OpenAI

# %%
client = OpenAI(api_key="")

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

# %%
print(completion.choices[0].message.content)
# Out:
# Hello! How can I assist you today?

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    top_p=0.9
)
print(completion.choices[0].message.content)
# Out:
# Hello! How can I assist you today?

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    temperature=1.8
)
print(completion.choices[0].message.content)
# Out:
# Hello! How can I assist you today?
